# %%
import random as rd

# 행의 개수 nRows, 열의 개수 nColumns
distance = [ ]

#길이가 랜덤하면 값범위가 너무 길다. 제한해준다
nRows = 20
nColumns = 20

for i in range(nRows) :
  row = [ ]
  for j in range(nColumns) :
    row.append(rd.randint(0,99))
  distance.append(row)

for row in distance :
  print(row)
# Out:
# [38, 90, 5, 7, 19, 84, 62, 6, 39, 13, 66, 32, 90, 5, 24, 13, 59, 24, 63, 57]
# [95, 63, 7, 99, 11, 13, 75, 79, 82, 45, 37, 19, 61, 56, 43, 4, 94, 38, 69, 45]
# [1, 67, 58, 98, 12, 84, 58, 43, 34, 83, 93, 64, 23, 79, 93, 22, 63, 54, 11, 50]
# [49, 20, 56, 91, 33, 86, 10, 36, 79, 81, 40, 62, 58, 3, 61, 6, 18, 42, 60, 9]
# [65, 19, 75, 47, 22, 18, 76, 39, 97, 50, 70, 3, 29, 25, 71, 35, 38, 25, 88, 34]
# [81, 15, 22, 52, 82, 69, 26, 93, 40, 53, 12, 93, 87, 71, 92, 78, 34, 52, 48, 22]
# [24, 63, 6, 76, 33, 15, 56, 7, 78, 10, 27, 73, 97, 18, 49, 69, 21, 22, 22, 56]
# [84, 16, 97, 32, 64, 33, 11, 8, 70, 31, 52, 89, 60, 71, 92, 75, 20, 7, 17, 38]
# [33, 66, 6, 99, 83, 0, 89, 81, 43, 96, 29, 45, 38, 42, 73, 46, 73, 16, 44, 32]
# [16, 29, 37, 42, 17, 76, 65, 35, 88, 33, 68, 15, 0, 54, 81, 8, 38, 74, 99, 8]
# [63, 91, 16, 64, 21, 38, 58, 72, 5, 99, 36, 63, 59, 11, 35, 21, 5, 91, 55, 96]
# [25, 9, 22, 93, 82, 88, 75, 67, 44, 22, 65, 14, 64, 62, 17, 86, 94, 22, 78, 76]
# ...
