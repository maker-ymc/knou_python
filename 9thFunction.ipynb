# %%
#원뿔 부피 계산 함수 정의
def prt_cone_vol1(r, h) :
  if r > 0 and h>0 :
    vol= 1/3*3.14*r**2*h
    return vol
  else :
    print("반지름과 높이의 값을 모두 양수로 입력해주세요")

#함수호출

print(format(prt_cone_vol1(10, 20), "<20.3f"), "입니다.")
# Out:
# 2093.333             입니다.

# %% [markdown]
# ## 원뿔 부피 밑 겉넓이 반환 함수 정의

# %%
#원뿔 겉넓이 계산 함수 정의
def prt_cone_suf(r,h) :
  if r > 0 and h>0 :
    vol= 1/3*3.14*r**2*h
    suf = 3.14*r**2+3.14*r*h
    return vol, suf
  else :
    print("반지름과 높이의 값을 모두 양수로 입력해주세요")

#함수호출

vol1, suf1 = prt_cone_suf(50, 100)
print(vol1, "입니다")
print(suf1, "입니다")
# Out:
# 261666.66666666666 입니다
# 23550.0 입니다

# %% [markdown]
# ## 숫자를 입력받고 역순으로 출력하는 함수를 사용한 프로그램 문제

# %%
digits=34567

def reverse_number(num) :
  while num !=0 :
    digit =num %10
    num=num//10
    print(digit, end="")

reverse_number(digits)
# Out:
# 76543

# %% [markdown]
# ## 세 개의 사용자 입력을 오름차순으로 정렬하는 함수를 이용하여 정렬된 값을 출력

# %%
a=int(input("첫번째 숫자를 입력하세요"))
b=int(input("두번째 숫자를 입력하세요"))
c=int(input("세번째 숫자를 입력하세요"))

def sort3(a, b, c) :
  if a>b :
    a, b = b, a
  if a>c :
    a, c = c, a
  if b>c :
    b, c = c, b
  print(a, b, c)

sort3(a, b, c)
print("출력 후", a, b, c)
# Out:
# 첫번째 숫자를 입력하세요6
# 두번째 숫자를 입력하세요3
# 세번째 숫자를 입력하세요9
# 3 6 9
# 출력 후 6 3 9

# %% [markdown]
# ## 변수의 스코프

# %%
def rtn_cone_vol2(r, h) :
  if r>0 and h>0 :
    vol = 1/3*3.14*r**2*h
    return vol
  else :
    print("반지름과 높이 값에 양수를 입력하세요")

radius=50
height=100
print(format(rtn_cone_vol2(radius, height), ">10.3f"))
print("함수 사용 후", radius, height)
# Out:
# 261666.667
# 함수 사용 후 50 100

# %% [markdown]
# ## 여러개의 수를 입력받고 합과 평균을 반환하는 함수

# %%
def var_sum_avg(*numbers) :
  sum=0
  count=0

  for i in numbers :
    sum = sum + i
    count = count + 1

  return sum, sum/count

print(var_sum_avg(10,20,30,40, 50, 60))
# Out:
# (210, 35.0)
