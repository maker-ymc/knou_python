# %% [markdown]
# # 4강 1절

# %%
3.141592
# Out:
# 3.141592

# %%
"Computer"
# Out:
# 'Computer'

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
(7+15)*2
# Out:
# 44

# %%
2**10*5
# Out:
# 5120

# %%
"computer"+"science" #competination(?)
# Out:
# 'computerscience'

# %%
"computer"*2
# Out:
# 'computercomputer'

# %%
print(2*7)  # 데이터가 다르게 출력되거나, 여러개의 값을 출력해야할때 print를 사용합니다.
# Out:
# 14

# %%
print("Hello World!")
print("Python is Fun")
# Out:
# Hello World!
# Python is Fun

# %% [markdown]
# 학점계산

# %%
# 학점 계산
print((4.5*2+4.0*3)/2)
# Out:
# 10.5

# %% [markdown]
# # 4강 2절
#
# 원뿔의 부피와 겉넓이를 구해봤다

# %%
#반지름, 높이 값 할당
rad = 40
hei = 10
pai = 3.14

#부피 출력
print(1 * 3 * pai * rad ** 2 * hei)
#겉넓이 출력
print(pai * rad **2 + pai * rad * hei)
# Out:
# 150720.0
# 6280.0

# %% [markdown]
# # 4강 3절

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
25%7
# Out:
# 4

# %%
8.4%0.9
# Out:
# 0.30000000000000016

# %%
number = 10
if number % 2 == 0:
    result = "짝수"
else:
    result = "홀수"

print(result)
# Out:
# 짝수
